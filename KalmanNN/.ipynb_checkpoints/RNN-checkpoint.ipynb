# %%
# standard imports
import os
import random
import numpy as np

# work with data
import pandas as pd
import h5py
import matplotlib.pyplot as plt
# %matplotlib inline
from mpl_toolkits.mplot3d import Axes3D

# like numpy, only good + NN
import torch, torch.nn as nn
import torch.nn.functional as torch_nn_F
# from torch.utils.data import Dataset

plt.rcParams[
    "figure.facecolor"
] = "w"  # force white background on plots when using dark mode in JupyterLab

# Dark plots
#plt.style.use('dark_background')
    
TIME_STEP = 1
CLASSNAME = {0: 'ballistic', 1: 'hgv', 2: 'hcm'}
CLASSTYPE = {'ballistic': 0, 'hgv': 1, 'hcm': 2}

# %% [markdown]
# # Prepare data
# ## Load and examine data

# %%
# Data reading function
def read_trajectories(path_to_file): 
    dset = pd.HDFStore(path_to_file, 'r')
    print(dset.info())
    return dset

# %%
# reading
name_file_trajectories = './data/ballistic_batch_1000_nopad.h5'
try:
    dset = read_trajectories(name_file_trajectories)
except FileNotFoundError:
    assert "NO file!!!"
# Out:
# <class 'pandas.io.pytables.HDFStore'>
# File path: ./data/ballistic_batch_1000_nopad.h5
# /ballistic_raw/BALLISTIC_1               frame        (shape->[290,8])
# /ballistic_raw/BALLISTIC_10              frame        (shape->[193,8])
# /ballistic_raw/BALLISTIC_100             frame        (shape->[378,8])
# /ballistic_raw/BALLISTIC_1000            frame        (shape->[340,8])
# /ballistic_raw/BALLISTIC_101             frame        (shape->[361,8])
# /ballistic_raw/BALLISTIC_102             frame        (shape->[297,8])
# /ballistic_raw/BALLISTIC_103             frame        (shape->[242,8])
# /ballistic_raw/BALLISTIC_104             frame        (shape->[170,8])
# /ballistic_raw/BALLISTIC_105             frame        (shape->[303,8])
# /ballistic_raw/BALLISTIC_106             frame        (shape->[199,8])
# /ballistic_raw/BALLISTIC_107             frame        (shape->[180,8])
# /ballistic_raw/BALLISTIC_108             frame        (shape->[179,8])
# /ballistic_raw/BALLISTIC_109             frame        (shape->[256,8])
# /ballistic_raw/BALLISTIC_11              frame        (shape->[185,8])
# /ballistic_raw/BALLISTIC_110             frame        (shape->[177,8])
# /ballistic_raw/BALLISTIC_111             frame        (shape->[261,8])
# /ballistic_raw/BALLISTIC_112             frame        (shape->[182,8])
# /ballistic_raw/BALLISTIC_113             frame        (shape->[261,8])
# /ballistic_raw/BALLISTIC_114             frame        (shape->[215,8])
# /ballistic_raw/BALLISTIC_115             frame        (shape->[399,8])
# /ballistic_raw/BALLISTIC_116             frame        (shape->[217,8])
# /ballistic_raw/BALLISTIC_117             frame        (shape->[188,8])
# /ballistic_raw/BALLISTIC_118             frame        (shape->[389,8])
# /ballistic_raw/BALLISTIC_119             frame        (shape->[191,8])
# /ballistic_raw/BALLISTIC_12              frame        (shape->[188,8])
# /ballistic_raw/BALLISTIC_120             frame        (shape->[392,8])
# /ballistic_raw/BALLISTIC_121             frame        (shape->[190,8])
# /ballistic_raw/BALLISTIC_122             frame        (shape->[401,8])
# /ballistic_raw/BALLISTIC_123             frame        (shape->[217,8])
# /ballistic_raw/BALLISTIC_124             frame        (shape->[274,8])
# /ballistic_raw/BALLISTIC_125             frame        (shape->[256,8])
# /ballistic_raw/BALLISTIC_126             frame        (shape->[320,8])
# /ballistic_raw/BALLISTIC_127             frame        (shape->[165,8])
# /ballistic_raw/BALLISTIC_128             frame        (shape->[195,8])
# /ballistic_raw/BALLISTIC_129             frame        (shape->[183,8])
# /ballistic_raw/BALLISTIC_13              frame        (shape->[185,8])
# /ballistic_raw/BALLISTIC_130             frame        (shape->[251,8])
# /ballistic_raw/BALLISTIC_131             frame        (shape->[282,8])
# /ballistic_raw/BALLISTIC_132             frame        (shape->[343,8])
# /ballistic_raw/BALLISTIC_133             frame        (shape->[356,8])
# /ballistic_raw/BALLISTIC_134             frame        (shape->[223,8])
# /ballistic_raw/BALLISTIC_135             frame        (shape->[182,8])
# /ballistic_raw/BALLISTIC_136             frame        (shape->[263,8])
# /ballistic_raw/BALLISTIC_137             frame        (shape->[233,8])
# /ballistic_raw/BALLISTIC_138             frame        (shape->[303,8])
# /ballistic_raw/BALLISTIC_139             frame        (shape->[377,8])
# /ballistic_raw/BALLISTIC_14              frame        (shape->[181,8])
# /ballistic_raw/BALLISTIC_140             frame        (shape->[225,8])
# /ballistic_raw/BALLISTIC_141             frame        (shape->[205,8])
# /ballistic_raw/BALLISTIC_142             frame        (shape->[181,8])
# /ballistic_raw/BALLISTIC_143             frame        (shape->[163,8])
# /ballistic_raw/BALLISTIC_144             frame        (shape->[268,8])
# /ballistic_raw/BALLISTIC_145             frame        (shape->[354,8])
# /ballistic_raw/BALLISTIC_146             frame        (shape->[181,8])
# /ballistic_raw/BALLISTIC_147             frame        (shape->[213,8])
# /ballistic_raw/BALLISTIC_148             frame        (shape->[390,8])
# /ballistic_raw/BALLISTIC_149             frame        (shape->[235,8])
# /ballistic_raw/BALLISTIC_15              frame        (shape->[182,8])
# /ballistic_raw/BALLISTIC_150             frame        (shape->[365,8])
# /ballistic_raw/BALLISTIC_151             frame        (shape->[389,8])
# /ballistic_raw/BALLISTIC_152             frame        (shape->[174,8])
# /ballistic_raw/BALLISTIC_153             frame        (shape->[189,8])
# /ballistic_raw/BALLISTIC_154             frame        (shape->[324,8])
# /ballistic_raw/BALLISTIC_155             frame        (shape->[344,8])
# /ballistic_raw/BALLISTIC_156             frame        (shape->[173,8])
# /ballistic_raw/BALLISTIC_157             frame        (shape->[262,8])
# /ballistic_raw/BALLISTIC_158             frame        (shape->[260,8])
# /ballistic_raw/BALLISTIC_159             frame        (shape->[251,8])
# /ballistic_raw/BALLISTIC_16              frame        (shape->[272,8])
# /ballistic_raw/BALLISTIC_160             frame        (shape->[182,8])
# /ballistic_raw/BALLISTIC_161             frame        (shape->[298,8])
# /ballistic_raw/BALLISTIC_162             frame        (shape->[235,8])
# /ballistic_raw/BALLISTIC_163             frame        (shape->[368,8])
# /ballistic_raw/BALLISTIC_164             frame        (shape->[287,8])
# /ballistic_raw/BALLISTIC_165             frame        (shape->[304,8])
# /ballistic_raw/BALLISTIC_166             frame        (shape->[199,8])
# /ballistic_raw/BALLISTIC_167             frame        (shape->[292,8])
# /ballistic_raw/BALLISTIC_168             frame        (shape->[354,8])
# /ballistic_raw/BALLISTIC_169             frame        (shape->[264,8])
# /ballistic_raw/BALLISTIC_17              frame        (shape->[220,8])
# /ballistic_raw/BALLISTIC_170             frame        (shape->[177,8])
# /ballistic_raw/BALLISTIC_171             frame        (shape->[186,8])
# /ballistic_raw/BALLISTIC_172             frame        (shape->[238,8])
# /ballistic_raw/BALLISTIC_173             frame        (shape->[206,8])
# /ballistic_raw/BALLISTIC_174             frame        (shape->[191,8])
# /ballistic_raw/BALLISTIC_175             frame        (shape->[239,8])
# /ballistic_raw/BALLISTIC_176             frame        (shape->[308,8])
# /ballistic_raw/BALLISTIC_177             frame        (shape->[298,8])
# /ballistic_raw/BALLISTIC_178             frame        (shape->[422,8])
# /ballistic_raw/BALLISTIC_179             frame        (shape->[214,8])
# /ballistic_raw/BALLISTIC_18              frame        (shape->[243,8])
# /ballistic_raw/BALLISTIC_180             frame        (shape->[384,8])
# /ballistic_raw/BALLISTIC_181             frame        (shape->[393,8])
# /ballistic_raw/BALLISTIC_182             frame        (shape->[220,8])
# /ballistic_raw/BALLISTIC_183             frame        (shape->[214,8])
# /ballistic_raw/BALLISTIC_184             frame        (shape->[290,8])
# /ballistic_raw/BALLISTIC_185             frame        (shape->[197,8])
# /ballistic_raw/BALLISTIC_186             frame        (shape->[178,8])
# /ballistic_raw/BALLISTIC_187             frame        (shape->[187,8])
# /ballistic_raw/BALLISTIC_188             frame        (shape->[189,8])
# /ballistic_raw/BALLISTIC_189             frame        (shape->[224,8])
# /ballistic_raw/BALLISTIC_19              frame        (shape->[448,8])
# /ballistic_raw/BALLISTIC_190             frame        (shape->[177,8])
# /ballistic_raw/BALLISTIC_191             frame        (shape->[177,8])
# /ballistic_raw/BALLISTIC_192             frame        (shape->[242,8])
# /ballistic_raw/BALLISTIC_193             frame        (shape->[278,8])
# /ballistic_raw/BALLISTIC_194             frame        (shape->[262,8])
# /ballistic_raw/BALLISTIC_195             frame        (shape->[266,8])
# /ballistic_raw/BALLISTIC_196             frame        (shape->[367,8])
# /ballistic_raw/BALLISTIC_197             frame        (shape->[231,8])
# /ballistic_raw/BALLISTIC_198             frame        (shape->[249,8])
# /ballistic_raw/BALLISTIC_199             frame        (shape->[294,8])
# /ballistic_raw/BALLISTIC_2               frame        (shape->[357,8])
# /ballistic_raw/BALLISTIC_20              frame        (shape->[230,8])
# /ballistic_raw/BALLISTIC_200             frame        (shape->[225,8])
# /ballistic_raw/BALLISTIC_201             frame        (shape->[248,8])
# /ballistic_raw/BALLISTIC_202             frame        (shape->[352,8])
# /ballistic_raw/BALLISTIC_203             frame        (shape->[221,8])
# /ballistic_raw/BALLISTIC_204             frame        (shape->[205,8])
# /ballistic_raw/BALLISTIC_205             frame        (shape->[270,8])
# /ballistic_raw/BALLISTIC_206             frame        (shape->[249,8])
# /ballistic_raw/BALLISTIC_207             frame        (shape->[166,8])
# /ballistic_raw/BALLISTIC_208             frame        (shape->[305,8])
# /ballistic_raw/BALLISTIC_209             frame        (shape->[259,8])
# /ballistic_raw/BALLISTIC_21              frame        (shape->[199,8])
# /ballistic_raw/BALLISTIC_210             frame        (shape->[168,8])
# /ballistic_raw/BALLISTIC_211             frame        (shape->[348,8])
# /ballistic_raw/BALLISTIC_212             frame        (shape->[247,8])
# /ballistic_raw/BALLISTIC_213             frame        (shape->[201,8])
# /ballistic_raw/BALLISTIC_214             frame        (shape->[340,8])
# /ballistic_raw/BALLISTIC_215             frame        (shape->[245,8])
# /ballistic_raw/BALLISTIC_216             frame        (shape->[213,8])
# /ballistic_raw/BALLISTIC_217             frame        (shape->[257,8])
# /ballistic_raw/BALLISTIC_218             frame        (shape->[171,8])
# /ballistic_raw/BALLISTIC_219             frame        (shape->[331,8])
# /ballistic_raw/BALLISTIC_22              frame        (shape->[378,8])
# /ballistic_raw/BALLISTIC_220             frame        (shape->[415,8])
# /ballistic_raw/BALLISTIC_221             frame        (shape->[211,8])
# /ballistic_raw/BALLISTIC_222             frame        (shape->[362,8])
# /ballistic_raw/BALLISTIC_223             frame        (shape->[348,8])
# /ballistic_raw/BALLISTIC_224             frame        (shape->[218,8])
# /ballistic_raw/BALLISTIC_225             frame        (shape->[169,8])
# /ballistic_raw/BALLISTIC_226             frame        (shape->[369,8])
# /ballistic_raw/BALLISTIC_227             frame        (shape->[172,8])
# /ballistic_raw/BALLISTIC_228             frame        (shape->[189,8])
# /ballistic_raw/BALLISTIC_229             frame        (shape->[349,8])
# /ballistic_raw/BALLISTIC_23              frame        (shape->[357,8])
# /ballistic_raw/BALLISTIC_230             frame        (shape->[290,8])
# /ballistic_raw/BALLISTIC_231             frame        (shape->[186,8])
# /ballistic_raw/BALLISTIC_232             frame        (shape->[193,8])
# /ballistic_raw/BALLISTIC_233             frame        (shape->[221,8])
# /ballistic_raw/BALLISTIC_234             frame        (shape->[310,8])
# /ballistic_raw/BALLISTIC_235             frame        (shape->[224,8])
# /ballistic_raw/BALLISTIC_236             frame        (shape->[205,8])
# /ballistic_raw/BALLISTIC_237             frame        (shape->[214,8])
# /ballistic_raw/BALLISTIC_238             frame        (shape->[192,8])
# /ballistic_raw/BALLISTIC_239             frame        (shape->[311,8])
# /ballistic_raw/BALLISTIC_24              frame        (shape->[166,8])
# /ballistic_raw/BALLISTIC_240             frame        (shape->[368,8])
# /ballistic_raw/BALLISTIC_241             frame        (shape->[292,8])
# /ballistic_raw/BALLISTIC_242             frame        (shape->[190,8])
# /ballistic_raw/BALLISTIC_243             frame        (shape->[175,8])
# /ballistic_raw/BALLISTIC_244             frame        (shape->[222,8])
# /ballistic_raw/BALLISTIC_245             frame        (shape->[175,8])
# /ballistic_raw/BALLISTIC_246             frame        (shape->[273,8])
# /ballistic_raw/BALLISTIC_247             frame        (shape->[248,8])
# /ballistic_raw/BALLISTIC_248             frame        (shape->[262,8])
# /ballistic_raw/BALLISTIC_249             frame        (shape->[222,8])
# /ballistic_raw/BALLISTIC_25              frame        (shape->[360,8])
# /ballistic_raw/BALLISTIC_250             frame        (shape->[310,8])
# /ballistic_raw/BALLISTIC_251             frame        (shape->[164,8])
# /ballistic_raw/BALLISTIC_252             frame        (shape->[201,8])
# /ballistic_raw/BALLISTIC_253             frame        (shape->[180,8])
# /ballistic_raw/BALLISTIC_254             frame        (shape->[445,8])
# /ballistic_raw/BALLISTIC_255             frame        (shape->[296,8])
# /ballistic_raw/BALLISTIC_256             frame        (shape->[205,8])
# /ballistic_raw/BALLISTIC_257             frame        (shape->[256,8])
# /ballistic_raw/BALLISTIC_258             frame        (shape->[189,8])
# /ballistic_raw/BALLISTIC_259             frame        (shape->[324,8])
# /ballistic_raw/BALLISTIC_26              frame        (shape->[183,8])
# /ballistic_raw/BALLISTIC_260             frame        (shape->[242,8])
# /ballistic_raw/BALLISTIC_261             frame        (shape->[353,8])
# /ballistic_raw/BALLISTIC_262             frame        (shape->[377,8])
# /ballistic_raw/BALLISTIC_263             frame        (shape->[356,8])
# /ballistic_raw/BALLISTIC_264             frame        (shape->[162,8])
# /ballistic_raw/BALLISTIC_265             frame        (shape->[277,8])
# /ballistic_raw/BALLISTIC_266             frame        (shape->[245,8])
# /ballistic_raw/BALLISTIC_267             frame        (shape->[233,8])
# /ballistic_raw/BALLISTIC_268             frame        (shape->[185,8])
# /ballistic_raw/BALLISTIC_269             frame        (shape->[272,8])
# /ballistic_raw/BALLISTIC_27              frame        (shape->[254,8])
# /ballistic_raw/BALLISTIC_270             frame        (shape->[310,8])
# /ballistic_raw/BALLISTIC_271             frame        (shape->[188,8])
# /ballistic_raw/BALLISTIC_272             frame        (shape->[368,8])
# /ballistic_raw/BALLISTIC_273             frame        (shape->[269,8])
# /ballistic_raw/BALLISTIC_274             frame        (shape->[438,8])
# /ballistic_raw/BALLISTIC_275             frame        (shape->[378,8])
# /ballistic_raw/BALLISTIC_276             frame        (shape->[283,8])
# /ballistic_raw/BALLISTIC_277             frame        (shape->[246,8])
# /ballistic_raw/BALLISTIC_278             frame        (shape->[178,8])
# /ballistic_raw/BALLISTIC_279             frame        (shape->[215,8])
# /ballistic_raw/BALLISTIC_28              frame        (shape->[290,8])
# /ballistic_raw/BALLISTIC_280             frame        (shape->[186,8])
# /ballistic_raw/BALLISTIC_281             frame        (shape->[369,8])
# /ballistic_raw/BALLISTIC_282             frame        (shape->[399,8])
# /ballistic_raw/BALLISTIC_283             frame        (shape->[286,8])
# /ballistic_raw/BALLISTIC_284             frame        (shape->[187,8])
# /ballistic_raw/BALLISTIC_285             frame        (shape->[232,8])
# /ballistic_raw/BALLISTIC_286             frame        (shape->[331,8])
# /ballistic_raw/BALLISTIC_287             frame        (shape->[206,8])
# /ballistic_raw/BALLISTIC_288             frame        (shape->[320,8])
# /ballistic_raw/BALLISTIC_289             frame        (shape->[274,8])
# /ballistic_raw/BALLISTIC_29              frame        (shape->[201,8])
# /ballistic_raw/BALLISTIC_290             frame        (shape->[219,8])
# /ballistic_raw/BALLISTIC_291             frame        (shape->[206,8])
# /ballistic_raw/BALLISTIC_292             frame        (shape->[297,8])
# /ballistic_raw/BALLISTIC_293             frame        (shape->[198,8])
# /ballistic_raw/BALLISTIC_294             frame        (shape->[322,8])
# /ballistic_raw/BALLISTIC_295             frame        (shape->[320,8])
# /ballistic_raw/BALLISTIC_296             frame        (shape->[198,8])
# /ballistic_raw/BALLISTIC_297             frame        (shape->[278,8])
# /ballistic_raw/BALLISTIC_298             frame        (shape->[201,8])
# /ballistic_raw/BALLISTIC_299             frame        (shape->[227,8])
# /ballistic_raw/BALLISTIC_3               frame        (shape->[197,8])
# /ballistic_raw/BALLISTIC_30              frame        (shape->[185,8])
# /ballistic_raw/BALLISTIC_300             frame        (shape->[213,8])
# /ballistic_raw/BALLISTIC_301             frame        (shape->[192,8])
# /ballistic_raw/BALLISTIC_302             frame        (shape->[244,8])
# /ballistic_raw/BALLISTIC_303             frame        (shape->[291,8])
# /ballistic_raw/BALLISTIC_304             frame        (shape->[350,8])
# /ballistic_raw/BALLISTIC_305             frame        (shape->[196,8])
# /ballistic_raw/BALLISTIC_306             frame        (shape->[168,8])
# /ballistic_raw/BALLISTIC_307             frame        (shape->[172,8])
# /ballistic_raw/BALLISTIC_308             frame        (shape->[275,8])
# /ballistic_raw/BALLISTIC_309             frame        (shape->[400,8])
# /ballistic_raw/BALLISTIC_31              frame        (shape->[429,8])
# /ballistic_raw/BALLISTIC_310             frame        (shape->[185,8])
# /ballistic_raw/BALLISTIC_311             frame        (shape->[220,8])
# /ballistic_raw/BALLISTIC_312             frame        (shape->[222,8])
# /ballistic_raw/BALLISTIC_313             frame        (shape->[190,8])
# /ballistic_raw/BALLISTIC_314             frame        (shape->[411,8])
# /ballistic_raw/BALLISTIC_315             frame        (shape->[183,8])
# /ballistic_raw/BALLISTIC_316             frame        (shape->[242,8])
# /ballistic_raw/BALLISTIC_317             frame        (shape->[190,8])
# /ballistic_raw/BALLISTIC_318             frame        (shape->[290,8])
# /ballistic_raw/BALLISTIC_319             frame        (shape->[237,8])
# /ballistic_raw/BALLISTIC_32              frame        (shape->[382,8])
# /ballistic_raw/BALLISTIC_320             frame        (shape->[168,8])
# /ballistic_raw/BALLISTIC_321             frame        (shape->[268,8])
# /ballistic_raw/BALLISTIC_322             frame        (shape->[198,8])
# /ballistic_raw/BALLISTIC_323             frame        (shape->[272,8])
# /ballistic_raw/BALLISTIC_324             frame        (shape->[370,8])
# /ballistic_raw/BALLISTIC_325             frame        (shape->[338,8])
# /ballistic_raw/BALLISTIC_326             frame        (shape->[196,8])
# /ballistic_raw/BALLISTIC_327             frame        (shape->[219,8])
# /ballistic_raw/BALLISTIC_328             frame        (shape->[291,8])
# /ballistic_raw/BALLISTIC_329             frame        (shape->[245,8])
# /ballistic_raw/BALLISTIC_33              frame        (shape->[194,8])
# /ballistic_raw/BALLISTIC_330             frame        (shape->[306,8])
# /ballistic_raw/BALLISTIC_331             frame        (shape->[171,8])
# /ballistic_raw/BALLISTIC_332             frame        (shape->[200,8])
# /ballistic_raw/BALLISTIC_333             frame        (shape->[301,8])
# /ballistic_raw/BALLISTIC_334             frame        (shape->[246,8])
# /ballistic_raw/BALLISTIC_335             frame        (shape->[372,8])
# /ballistic_raw/BALLISTIC_336             frame        (shape->[216,8])
# /ballistic_raw/BALLISTIC_337             frame        (shape->[181,8])
# /ballistic_raw/BALLISTIC_338             frame        (shape->[332,8])
# /ballistic_raw/BALLISTIC_339             frame        (shape->[385,8])
# /ballistic_raw/BALLISTIC_34              frame        (shape->[197,8])
# /ballistic_raw/BALLISTIC_340             frame        (shape->[302,8])
# /ballistic_raw/BALLISTIC_341             frame        (shape->[179,8])
# /ballistic_raw/BALLISTIC_342             frame        (shape->[221,8])
# /ballistic_raw/BALLISTIC_343             frame        (shape->[384,8])
# /ballistic_raw/BALLISTIC_344             frame        (shape->[416,8])
# /ballistic_raw/BALLISTIC_345             frame        (shape->[266,8])
# /ballistic_raw/BALLISTIC_346             frame        (shape->[308,8])
# /ballistic_raw/BALLISTIC_347             frame        (shape->[235,8])
# /ballistic_raw/BALLISTIC_348             frame        (shape->[405,8])
# /ballistic_raw/BALLISTIC_349             frame        (shape->[231,8])
# /ballistic_raw/BALLISTIC_35              frame        (shape->[303,8])
# /ballistic_raw/BALLISTIC_350             frame        (shape->[192,8])
# /ballistic_raw/BALLISTIC_351             frame        (shape->[220,8])
# /ballistic_raw/BALLISTIC_352             frame        (shape->[245,8])
# /ballistic_raw/BALLISTIC_353             frame        (shape->[192,8])
# /ballistic_raw/BALLISTIC_354             frame        (shape->[265,8])
# /ballistic_raw/BALLISTIC_355             frame        (shape->[224,8])
# /ballistic_raw/BALLISTIC_356             frame        (shape->[190,8])
# /ballistic_raw/BALLISTIC_357             frame        (shape->[337,8])
# /ballistic_raw/BALLISTIC_358             frame        (shape->[186,8])
# /ballistic_raw/BALLISTIC_359             frame        (shape->[368,8])
# /ballistic_raw/BALLISTIC_36              frame        (shape->[239,8])
# /ballistic_raw/BALLISTIC_360             frame        (shape->[279,8])
# /ballistic_raw/BALLISTIC_361             frame        (shape->[181,8])
# /ballistic_raw/BALLISTIC_362             frame        (shape->[270,8])
# /ballistic_raw/BALLISTIC_363             frame        (shape->[201,8])
# /ballistic_raw/BALLISTIC_364             frame        (shape->[210,8])
# /ballistic_raw/BALLISTIC_365             frame        (shape->[186,8])
# /ballistic_raw/BALLISTIC_366             frame        (shape->[286,8])
# /ballistic_raw/BALLISTIC_367             frame        (shape->[183,8])
# /ballistic_raw/BALLISTIC_368             frame        (shape->[342,8])
# /ballistic_raw/BALLISTIC_369             frame        (shape->[187,8])
# /ballistic_raw/BALLISTIC_37              frame        (shape->[372,8])
# /ballistic_raw/BALLISTIC_370             frame        (shape->[207,8])
# /ballistic_raw/BALLISTIC_371             frame        (shape->[177,8])
# /ballistic_raw/BALLISTIC_372             frame        (shape->[243,8])
# /ballistic_raw/BALLISTIC_373             frame        (shape->[205,8])
# /ballistic_raw/BALLISTIC_374             frame        (shape->[251,8])
# /ballistic_raw/BALLISTIC_375             frame        (shape->[259,8])
# /ballistic_raw/BALLISTIC_376             frame        (shape->[210,8])
# /ballistic_raw/BALLISTIC_377             frame        (shape->[367,8])
# /ballistic_raw/BALLISTIC_378             frame        (shape->[403,8])
# /ballistic_raw/BALLISTIC_379             frame        (shape->[340,8])
# /ballistic_raw/BALLISTIC_38              frame        (shape->[379,8])
# /ballistic_raw/BALLISTIC_380             frame        (shape->[227,8])
# /ballistic_raw/BALLISTIC_381             frame        (shape->[185,8])
# /ballistic_raw/BALLISTIC_382             frame        (shape->[249,8])
# /ballistic_raw/BALLISTIC_383             frame        (shape->[261,8])
# /ballistic_raw/BALLISTIC_384             frame        (shape->[305,8])
# /ballistic_raw/BALLISTIC_385             frame        (shape->[217,8])
# /ballistic_raw/BALLISTIC_386             frame        (shape->[307,8])
# /ballistic_raw/BALLISTIC_387             frame        (shape->[263,8])
# /ballistic_raw/BALLISTIC_388             frame        (shape->[189,8])
# /ballistic_raw/BALLISTIC_389             frame        (shape->[227,8])
# /ballistic_raw/BALLISTIC_39              frame        (shape->[381,8])
# /ballistic_raw/BALLISTIC_390             frame        (shape->[251,8])
# /ballistic_raw/BALLISTIC_391             frame        (shape->[241,8])
# /ballistic_raw/BALLISTIC_392             frame        (shape->[196,8])
# /ballistic_raw/BALLISTIC_393             frame        (shape->[332,8])
# /ballistic_raw/BALLISTIC_394             frame        (shape->[175,8])
# /ballistic_raw/BALLISTIC_395             frame        (shape->[228,8])
# /ballistic_raw/BALLISTIC_396             frame        (shape->[308,8])
# /ballistic_raw/BALLISTIC_397             frame        (shape->[243,8])
# /ballistic_raw/BALLISTIC_398             frame        (shape->[310,8])
# /ballistic_raw/BALLISTIC_399             frame        (shape->[191,8])
# /ballistic_raw/BALLISTIC_4               frame        (shape->[187,8])
# /ballistic_raw/BALLISTIC_40              frame        (shape->[224,8])
# /ballistic_raw/BALLISTIC_400             frame        (shape->[197,8])
# /ballistic_raw/BALLISTIC_401             frame        (shape->[201,8])
# /ballistic_raw/BALLISTIC_402             frame        (shape->[206,8])
# /ballistic_raw/BALLISTIC_403             frame        (shape->[272,8])
# /ballistic_raw/BALLISTIC_404             frame        (shape->[430,8])
# /ballistic_raw/BALLISTIC_405             frame        (shape->[428,8])
# /ballistic_raw/BALLISTIC_406             frame        (shape->[181,8])
# /ballistic_raw/BALLISTIC_407             frame        (shape->[212,8])
# /ballistic_raw/BALLISTIC_408             frame        (shape->[388,8])
# /ballistic_raw/BALLISTIC_409             frame        (shape->[405,8])
# /ballistic_raw/BALLISTIC_41              frame        (shape->[188,8])
# /ballistic_raw/BALLISTIC_410             frame        (shape->[213,8])
# /ballistic_raw/BALLISTIC_411             frame        (shape->[237,8])
# /ballistic_raw/BALLISTIC_412             frame        (shape->[222,8])
# /ballistic_raw/BALLISTIC_413             frame        (shape->[217,8])
# /ballistic_raw/BALLISTIC_414             frame        (shape->[368,8])
# /ballistic_raw/BALLISTIC_415             frame        (shape->[183,8])
# /ballistic_raw/BALLISTIC_416             frame        (shape->[318,8])
# /ballistic_raw/BALLISTIC_417             frame        (shape->[380,8])
# /ballistic_raw/BALLISTIC_418             frame        (shape->[186,8])
# /ballistic_raw/BALLISTIC_419             frame        (shape->[267,8])
# /ballistic_raw/BALLISTIC_42              frame        (shape->[209,8])
# /ballistic_raw/BALLISTIC_420             frame        (shape->[350,8])
# /ballistic_raw/BALLISTIC_421             frame        (shape->[185,8])
# /ballistic_raw/BALLISTIC_422             frame        (shape->[187,8])
# /ballistic_raw/BALLISTIC_423             frame        (shape->[233,8])
# /ballistic_raw/BALLISTIC_424             frame        (shape->[338,8])
# /ballistic_raw/BALLISTIC_425             frame        (shape->[239,8])
# /ballistic_raw/BALLISTIC_426             frame        (shape->[366,8])
# /ballistic_raw/BALLISTIC_427             frame        (shape->[282,8])
# /ballistic_raw/BALLISTIC_428             frame        (shape->[431,8])
# /ballistic_raw/BALLISTIC_429             frame        (shape->[211,8])
# /ballistic_raw/BALLISTIC_43              frame        (shape->[307,8])
# /ballistic_raw/BALLISTIC_430             frame        (shape->[294,8])
# /ballistic_raw/BALLISTIC_431             frame        (shape->[329,8])
# /ballistic_raw/BALLISTIC_432             frame        (shape->[300,8])
# /ballistic_raw/BALLISTIC_433             frame        (shape->[349,8])
# /ballistic_raw/BALLISTIC_434             frame        (shape->[359,8])
# /ballistic_raw/BALLISTIC_435             frame        (shape->[250,8])
# /ballistic_raw/BALLISTIC_436             frame        (shape->[260,8])
# /ballistic_raw/BALLISTIC_437             frame        (shape->[233,8])
# /ballistic_raw/BALLISTIC_438             frame        (shape->[311,8])
# /ballistic_raw/BALLISTIC_439             frame        (shape->[359,8])
# /ballistic_raw/BALLISTIC_44              frame        (shape->[193,8])
# /ballistic_raw/BALLISTIC_440             frame        (shape->[201,8])
# /ballistic_raw/BALLISTIC_441             frame        (shape->[279,8])
# /ballistic_raw/BALLISTIC_442             frame        (shape->[220,8])
# /ballistic_raw/BALLISTIC_443             frame        (shape->[401,8])
# /ballistic_raw/BALLISTIC_444             frame        (shape->[182,8])
# /ballistic_raw/BALLISTIC_445             frame        (shape->[190,8])
# /ballistic_raw/BALLISTIC_446             frame        (shape->[265,8])
# /ballistic_raw/BALLISTIC_447             frame        (shape->[411,8])
# /ballistic_raw/BALLISTIC_448             frame        (shape->[201,8])
# /ballistic_raw/BALLISTIC_449             frame        (shape->[201,8])
# /ballistic_raw/BALLISTIC_45              frame        (shape->[266,8])
# /ballistic_raw/BALLISTIC_450             frame        (shape->[278,8])
# /ballistic_raw/BALLISTIC_451             frame        (shape->[401,8])
# /ballistic_raw/BALLISTIC_452             frame        (shape->[398,8])
# /ballistic_raw/BALLISTIC_453             frame        (shape->[179,8])
# /ballistic_raw/BALLISTIC_454             frame        (shape->[184,8])
# /ballistic_raw/BALLISTIC_455             frame        (shape->[269,8])
# /ballistic_raw/BALLISTIC_456             frame        (shape->[247,8])
# /ballistic_raw/BALLISTIC_457             frame        (shape->[233,8])
# /ballistic_raw/BALLISTIC_458             frame        (shape->[217,8])
# /ballistic_raw/BALLISTIC_459             frame        (shape->[209,8])
# /ballistic_raw/BALLISTIC_46              frame        (shape->[281,8])
# /ballistic_raw/BALLISTIC_460             frame        (shape->[273,8])
# /ballistic_raw/BALLISTIC_461             frame        (shape->[181,8])
# /ballistic_raw/BALLISTIC_462             frame        (shape->[208,8])
# /ballistic_raw/BALLISTIC_463             frame        (shape->[226,8])
# /ballistic_raw/BALLISTIC_464             frame        (shape->[218,8])
# /ballistic_raw/BALLISTIC_465             frame        (shape->[401,8])
# /ballistic_raw/BALLISTIC_466             frame        (shape->[260,8])
# /ballistic_raw/BALLISTIC_467             frame        (shape->[195,8])
# /ballistic_raw/BALLISTIC_468             frame        (shape->[199,8])
# /ballistic_raw/BALLISTIC_469             frame        (shape->[426,8])
# /ballistic_raw/BALLISTIC_47              frame        (shape->[255,8])
# /ballistic_raw/BALLISTIC_470             frame        (shape->[379,8])
# /ballistic_raw/BALLISTIC_471             frame        (shape->[271,8])
# /ballistic_raw/BALLISTIC_472             frame        (shape->[294,8])
# /ballistic_raw/BALLISTIC_473             frame        (shape->[227,8])
# /ballistic_raw/BALLISTIC_474             frame        (shape->[263,8])
# /ballistic_raw/BALLISTIC_475             frame        (shape->[271,8])
# /ballistic_raw/BALLISTIC_476             frame        (shape->[224,8])
# /ballistic_raw/BALLISTIC_477             frame        (shape->[449,8])
# /ballistic_raw/BALLISTIC_478             frame        (shape->[186,8])
# /ballistic_raw/BALLISTIC_479             frame        (shape->[328,8])
# /ballistic_raw/BALLISTIC_48              frame        (shape->[185,8])
# /ballistic_raw/BALLISTIC_480             frame        (shape->[171,8])
# /ballistic_raw/BALLISTIC_481             frame        (shape->[303,8])
# /ballistic_raw/BALLISTIC_482             frame        (shape->[206,8])
# /ballistic_raw/BALLISTIC_483             frame        (shape->[296,8])
# /ballistic_raw/BALLISTIC_484             frame        (shape->[223,8])
# /ballistic_raw/BALLISTIC_485             frame        (shape->[212,8])
# /ballistic_raw/BALLISTIC_486             frame        (shape->[194,8])
# /ballistic_raw/BALLISTIC_487             frame        (shape->[251,8])
# /ballistic_raw/BALLISTIC_488             frame        (shape->[184,8])
# /ballistic_raw/BALLISTIC_489             frame        (shape->[354,8])
# /ballistic_raw/BALLISTIC_49              frame        (shape->[308,8])
# /ballistic_raw/BALLISTIC_490             frame        (shape->[246,8])
# /ballistic_raw/BALLISTIC_491             frame        (shape->[386,8])
# /ballistic_raw/BALLISTIC_492             frame        (shape->[193,8])
# /ballistic_raw/BALLISTIC_493             frame        (shape->[176,8])
# /ballistic_raw/BALLISTIC_494             frame        (shape->[218,8])
# /ballistic_raw/BALLISTIC_495             frame        (shape->[185,8])
# /ballistic_raw/BALLISTIC_496             frame        (shape->[243,8])
# /ballistic_raw/BALLISTIC_497             frame        (shape->[215,8])
# /ballistic_raw/BALLISTIC_498             frame        (shape->[202,8])
# /ballistic_raw/BALLISTIC_499             frame        (shape->[244,8])
# /ballistic_raw/BALLISTIC_5               frame        (shape->[350,8])
# /ballistic_raw/BALLISTIC_50              frame        (shape->[314,8])
# /ballistic_raw/BALLISTIC_500             frame        (shape->[168,8])
# /ballistic_raw/BALLISTIC_501             frame        (shape->[202,8])
# /ballistic_raw/BALLISTIC_502             frame        (shape->[419,8])
# /ballistic_raw/BALLISTIC_503             frame        (shape->[366,8])
# /ballistic_raw/BALLISTIC_504             frame        (shape->[348,8])
# /ballistic_raw/BALLISTIC_505             frame        (shape->[341,8])
# /ballistic_raw/BALLISTIC_506             frame        (shape->[352,8])
# /ballistic_raw/BALLISTIC_507             frame        (shape->[266,8])
# /ballistic_raw/BALLISTIC_508             frame        (shape->[240,8])
# /ballistic_raw/BALLISTIC_509             frame        (shape->[173,8])
# /ballistic_raw/BALLISTIC_51              frame        (shape->[189,8])
# /ballistic_raw/BALLISTIC_510             frame        (shape->[406,8])
# /ballistic_raw/BALLISTIC_511             frame        (shape->[196,8])
# /ballistic_raw/BALLISTIC_512             frame        (shape->[168,8])
# /ballistic_raw/BALLISTIC_513             frame        (shape->[238,8])
# /ballistic_raw/BALLISTIC_514             frame        (shape->[186,8])
# /ballistic_raw/BALLISTIC_515             frame        (shape->[396,8])
# /ballistic_raw/BALLISTIC_516             frame        (shape->[368,8])
# /ballistic_raw/BALLISTIC_517             frame        (shape->[300,8])
# /ballistic_raw/BALLISTIC_518             frame        (shape->[178,8])
# /ballistic_raw/BALLISTIC_519             frame        (shape->[278,8])
# /ballistic_raw/BALLISTIC_52              frame        (shape->[276,8])
# /ballistic_raw/BALLISTIC_520             frame        (shape->[195,8])
# /ballistic_raw/BALLISTIC_521             frame        (shape->[249,8])
# /ballistic_raw/BALLISTIC_522             frame        (shape->[182,8])
# /ballistic_raw/BALLISTIC_523             frame        (shape->[211,8])
# /ballistic_raw/BALLISTIC_524             frame        (shape->[396,8])
# /ballistic_raw/BALLISTIC_525             frame        (shape->[171,8])
# /ballistic_raw/BALLISTIC_526             frame        (shape->[234,8])
# /ballistic_raw/BALLISTIC_527             frame        (shape->[223,8])
# /ballistic_raw/BALLISTIC_528             frame        (shape->[243,8])
# /ballistic_raw/BALLISTIC_529             frame        (shape->[222,8])
# /ballistic_raw/BALLISTIC_53              frame        (shape->[403,8])
# /ballistic_raw/BALLISTIC_530             frame        (shape->[303,8])
# /ballistic_raw/BALLISTIC_531             frame        (shape->[287,8])
# /ballistic_raw/BALLISTIC_532             frame        (shape->[353,8])
# /ballistic_raw/BALLISTIC_533             frame        (shape->[310,8])
# /ballistic_raw/BALLISTIC_534             frame        (shape->[387,8])
# /ballistic_raw/BALLISTIC_535             frame        (shape->[181,8])
# /ballistic_raw/BALLISTIC_536             frame        (shape->[236,8])
# /ballistic_raw/BALLISTIC_537             frame        (shape->[184,8])
# /ballistic_raw/BALLISTIC_538             frame        (shape->[230,8])
# /ballistic_raw/BALLISTIC_539             frame        (shape->[180,8])
# /ballistic_raw/BALLISTIC_54              frame        (shape->[242,8])
# /ballistic_raw/BALLISTIC_540             frame        (shape->[345,8])
# /ballistic_raw/BALLISTIC_541             frame        (shape->[164,8])
# /ballistic_raw/BALLISTIC_542             frame        (shape->[406,8])
# /ballistic_raw/BALLISTIC_543             frame        (shape->[341,8])
# /ballistic_raw/BALLISTIC_544             frame        (shape->[170,8])
# /ballistic_raw/BALLISTIC_545             frame        (shape->[356,8])
# /ballistic_raw/BALLISTIC_546             frame        (shape->[173,8])
# /ballistic_raw/BALLISTIC_547             frame        (shape->[279,8])
# /ballistic_raw/BALLISTIC_548             frame        (shape->[250,8])
# /ballistic_raw/BALLISTIC_549             frame        (shape->[192,8])
# /ballistic_raw/BALLISTIC_55              frame        (shape->[201,8])
# /ballistic_raw/BALLISTIC_550             frame        (shape->[381,8])
# /ballistic_raw/BALLISTIC_551             frame        (shape->[376,8])
# /ballistic_raw/BALLISTIC_552             frame        (shape->[175,8])
# /ballistic_raw/BALLISTIC_553             frame        (shape->[203,8])
# /ballistic_raw/BALLISTIC_554             frame        (shape->[229,8])
# /ballistic_raw/BALLISTIC_555             frame        (shape->[401,8])
# /ballistic_raw/BALLISTIC_556             frame        (shape->[184,8])
# /ballistic_raw/BALLISTIC_557             frame        (shape->[334,8])
# /ballistic_raw/BALLISTIC_558             frame        (shape->[270,8])
# /ballistic_raw/BALLISTIC_559             frame        (shape->[266,8])
# /ballistic_raw/BALLISTIC_56              frame        (shape->[186,8])
# /ballistic_raw/BALLISTIC_560             frame        (shape->[209,8])
# /ballistic_raw/BALLISTIC_561             frame        (shape->[225,8])
# /ballistic_raw/BALLISTIC_562             frame        (shape->[288,8])
# /ballistic_raw/BALLISTIC_563             frame        (shape->[220,8])
# /ballistic_raw/BALLISTIC_564             frame        (shape->[343,8])
# /ballistic_raw/BALLISTIC_565             frame        (shape->[335,8])
# /ballistic_raw/BALLISTIC_566             frame        (shape->[316,8])
# /ballistic_raw/BALLISTIC_567             frame        (shape->[259,8])
# /ballistic_raw/BALLISTIC_568             frame        (shape->[222,8])
# /ballistic_raw/BALLISTIC_569             frame        (shape->[201,8])
# /ballistic_raw/BALLISTIC_57              frame        (shape->[276,8])
# /ballistic_raw/BALLISTIC_570             frame        (shape->[388,8])
# /ballistic_raw/BALLISTIC_571             frame        (shape->[336,8])
# /ballistic_raw/BALLISTIC_572             frame        (shape->[198,8])
# /ballistic_raw/BALLISTIC_573             frame        (shape->[215,8])
# /ballistic_raw/BALLISTIC_574             frame        (shape->[350,8])
# /ballistic_raw/BALLISTIC_575             frame        (shape->[401,8])
# /ballistic_raw/BALLISTIC_576             frame        (shape->[418,8])
# /ballistic_raw/BALLISTIC_577             frame        (shape->[280,8])
# /ballistic_raw/BALLISTIC_578             frame        (shape->[209,8])
# /ballistic_raw/BALLISTIC_579             frame        (shape->[289,8])
# /ballistic_raw/BALLISTIC_58              frame        (shape->[420,8])
# /ballistic_raw/BALLISTIC_580             frame        (shape->[202,8])
# /ballistic_raw/BALLISTIC_581             frame        (shape->[261,8])
# /ballistic_raw/BALLISTIC_582             frame        (shape->[198,8])
# /ballistic_raw/BALLISTIC_583             frame        (shape->[323,8])
# /ballistic_raw/BALLISTIC_584             frame        (shape->[416,8])
# /ballistic_raw/BALLISTIC_585             frame        (shape->[409,8])
# /ballistic_raw/BALLISTIC_586             frame        (shape->[281,8])
# /ballistic_raw/BALLISTIC_587             frame        (shape->[164,8])
# /ballistic_raw/BALLISTIC_588             frame        (shape->[184,8])
# /ballistic_raw/BALLISTIC_589             frame        (shape->[249,8])
# /ballistic_raw/BALLISTIC_59              frame        (shape->[390,8])
# /ballistic_raw/BALLISTIC_590             frame        (shape->[252,8])
# /ballistic_raw/BALLISTIC_591             frame        (shape->[169,8])
# /ballistic_raw/BALLISTIC_592             frame        (shape->[220,8])
# /ballistic_raw/BALLISTIC_593             frame        (shape->[175,8])
# /ballistic_raw/BALLISTIC_594             frame        (shape->[194,8])
# /ballistic_raw/BALLISTIC_595             frame        (shape->[254,8])
# /ballistic_raw/BALLISTIC_596             frame        (shape->[354,8])
# /ballistic_raw/BALLISTIC_597             frame        (shape->[293,8])
# /ballistic_raw/BALLISTIC_598             frame        (shape->[318,8])
# /ballistic_raw/BALLISTIC_599             frame        (shape->[342,8])
# /ballistic_raw/BALLISTIC_6               frame        (shape->[350,8])
# /ballistic_raw/BALLISTIC_60              frame        (shape->[352,8])
# /ballistic_raw/BALLISTIC_600             frame        (shape->[311,8])
# /ballistic_raw/BALLISTIC_601             frame        (shape->[350,8])
# /ballistic_raw/BALLISTIC_602             frame        (shape->[250,8])
# /ballistic_raw/BALLISTIC_603             frame        (shape->[221,8])
# /ballistic_raw/BALLISTIC_604             frame        (shape->[234,8])
# /ballistic_raw/BALLISTIC_605             frame        (shape->[430,8])
# /ballistic_raw/BALLISTIC_606             frame        (shape->[384,8])
# /ballistic_raw/BALLISTIC_607             frame        (shape->[199,8])
# /ballistic_raw/BALLISTIC_608             frame        (shape->[315,8])
# /ballistic_raw/BALLISTIC_609             frame        (shape->[197,8])
# /ballistic_raw/BALLISTIC_61              frame        (shape->[366,8])
# /ballistic_raw/BALLISTIC_610             frame        (shape->[188,8])
# /ballistic_raw/BALLISTIC_611             frame        (shape->[299,8])
# /ballistic_raw/BALLISTIC_612             frame        (shape->[238,8])
# /ballistic_raw/BALLISTIC_613             frame        (shape->[404,8])
# /ballistic_raw/BALLISTIC_614             frame        (shape->[223,8])
# /ballistic_raw/BALLISTIC_615             frame        (shape->[200,8])
# /ballistic_raw/BALLISTIC_616             frame        (shape->[191,8])
# /ballistic_raw/BALLISTIC_617             frame        (shape->[168,8])
# /ballistic_raw/BALLISTIC_618             frame        (shape->[197,8])
# /ballistic_raw/BALLISTIC_619             frame        (shape->[200,8])
# /ballistic_raw/BALLISTIC_62              frame        (shape->[215,8])
# /ballistic_raw/BALLISTIC_620             frame        (shape->[234,8])
# /ballistic_raw/BALLISTIC_621             frame        (shape->[294,8])
# /ballistic_raw/BALLISTIC_622             frame        (shape->[209,8])
# /ballistic_raw/BALLISTIC_623             frame        (shape->[348,8])
# /ballistic_raw/BALLISTIC_624             frame        (shape->[283,8])
# /ballistic_raw/BALLISTIC_625             frame        (shape->[356,8])
# /ballistic_raw/BALLISTIC_626             frame        (shape->[218,8])
# /ballistic_raw/BALLISTIC_627             frame        (shape->[191,8])
# /ballistic_raw/BALLISTIC_628             frame        (shape->[332,8])
# /ballistic_raw/BALLISTIC_629             frame        (shape->[246,8])
# /ballistic_raw/BALLISTIC_63              frame        (shape->[272,8])
# /ballistic_raw/BALLISTIC_630             frame        (shape->[373,8])
# /ballistic_raw/BALLISTIC_631             frame        (shape->[286,8])
# /ballistic_raw/BALLISTIC_632             frame        (shape->[287,8])
# /ballistic_raw/BALLISTIC_633             frame        (shape->[237,8])
# /ballistic_raw/BALLISTIC_634             frame        (shape->[181,8])
# /ballistic_raw/BALLISTIC_635             frame        (shape->[183,8])
# /ballistic_raw/BALLISTIC_636             frame        (shape->[268,8])
# /ballistic_raw/BALLISTIC_637             frame        (shape->[241,8])
# /ballistic_raw/BALLISTIC_638             frame        (shape->[175,8])
# /ballistic_raw/BALLISTIC_639             frame        (shape->[334,8])
# /ballistic_raw/BALLISTIC_64              frame        (shape->[242,8])
# /ballistic_raw/BALLISTIC_640             frame        (shape->[186,8])
# /ballistic_raw/BALLISTIC_641             frame        (shape->[270,8])
# /ballistic_raw/BALLISTIC_642             frame        (shape->[315,8])
# /ballistic_raw/BALLISTIC_643             frame        (shape->[181,8])
# /ballistic_raw/BALLISTIC_644             frame        (shape->[197,8])
# /ballistic_raw/BALLISTIC_645             frame        (shape->[169,8])
# /ballistic_raw/BALLISTIC_646             frame        (shape->[306,8])
# /ballistic_raw/BALLISTIC_647             frame        (shape->[170,8])
# /ballistic_raw/BALLISTIC_648             frame        (shape->[205,8])
# /ballistic_raw/BALLISTIC_649             frame        (shape->[204,8])
# /ballistic_raw/BALLISTIC_65              frame        (shape->[199,8])
# /ballistic_raw/BALLISTIC_650             frame        (shape->[181,8])
# /ballistic_raw/BALLISTIC_651             frame        (shape->[247,8])
# /ballistic_raw/BALLISTIC_652             frame        (shape->[419,8])
# /ballistic_raw/BALLISTIC_653             frame        (shape->[194,8])
# /ballistic_raw/BALLISTIC_654             frame        (shape->[171,8])
# /ballistic_raw/BALLISTIC_655             frame        (shape->[166,8])
# /ballistic_raw/BALLISTIC_656             frame        (shape->[203,8])
# /ballistic_raw/BALLISTIC_657             frame        (shape->[270,8])
# /ballistic_raw/BALLISTIC_658             frame        (shape->[180,8])
# /ballistic_raw/BALLISTIC_659             frame        (shape->[260,8])
# /ballistic_raw/BALLISTIC_66              frame        (shape->[217,8])
# /ballistic_raw/BALLISTIC_660             frame        (shape->[260,8])
# /ballistic_raw/BALLISTIC_661             frame        (shape->[364,8])
# /ballistic_raw/BALLISTIC_662             frame        (shape->[434,8])
# /ballistic_raw/BALLISTIC_663             frame        (shape->[406,8])
# /ballistic_raw/BALLISTIC_664             frame        (shape->[223,8])
# /ballistic_raw/BALLISTIC_665             frame        (shape->[458,8])
# /ballistic_raw/BALLISTIC_666             frame        (shape->[361,8])
# /ballistic_raw/BALLISTIC_667             frame        (shape->[303,8])
# /ballistic_raw/BALLISTIC_668             frame        (shape->[422,8])
# /ballistic_raw/BALLISTIC_669             frame        (shape->[396,8])
# /ballistic_raw/BALLISTIC_67              frame        (shape->[235,8])
# /ballistic_raw/BALLISTIC_670             frame        (shape->[385,8])
# /ballistic_raw/BALLISTIC_671             frame        (shape->[250,8])
# /ballistic_raw/BALLISTIC_672             frame        (shape->[178,8])
# /ballistic_raw/BALLISTIC_673             frame        (shape->[303,8])
# /ballistic_raw/BALLISTIC_674             frame        (shape->[217,8])
# /ballistic_raw/BALLISTIC_675             frame        (shape->[352,8])
# /ballistic_raw/BALLISTIC_676             frame        (shape->[190,8])
# /ballistic_raw/BALLISTIC_677             frame        (shape->[191,8])
# /ballistic_raw/BALLISTIC_678             frame        (shape->[233,8])
# /ballistic_raw/BALLISTIC_679             frame        (shape->[188,8])
# /ballistic_raw/BALLISTIC_68              frame        (shape->[374,8])
# /ballistic_raw/BALLISTIC_680             frame        (shape->[232,8])
# /ballistic_raw/BALLISTIC_681             frame        (shape->[385,8])
# /ballistic_raw/BALLISTIC_682             frame        (shape->[195,8])
# /ballistic_raw/BALLISTIC_683             frame        (shape->[365,8])
# /ballistic_raw/BALLISTIC_684             frame        (shape->[173,8])
# /ballistic_raw/BALLISTIC_685             frame        (shape->[183,8])
# /ballistic_raw/BALLISTIC_686             frame        (shape->[200,8])
# /ballistic_raw/BALLISTIC_687             frame        (shape->[266,8])
# /ballistic_raw/BALLISTIC_688             frame        (shape->[242,8])
# /ballistic_raw/BALLISTIC_689             frame        (shape->[304,8])
# /ballistic_raw/BALLISTIC_69              frame        (shape->[171,8])
# /ballistic_raw/BALLISTIC_690             frame        (shape->[449,8])
# /ballistic_raw/BALLISTIC_691             frame        (shape->[171,8])
# /ballistic_raw/BALLISTIC_692             frame        (shape->[244,8])
# /ballistic_raw/BALLISTIC_693             frame        (shape->[352,8])
# /ballistic_raw/BALLISTIC_694             frame        (shape->[394,8])
# /ballistic_raw/BALLISTIC_695             frame        (shape->[435,8])
# /ballistic_raw/BALLISTIC_696             frame        (shape->[199,8])
# /ballistic_raw/BALLISTIC_697             frame        (shape->[179,8])
# /ballistic_raw/BALLISTIC_698             frame        (shape->[324,8])
# /ballistic_raw/BALLISTIC_699             frame        (shape->[204,8])
# /ballistic_raw/BALLISTIC_7               frame        (shape->[224,8])
# /ballistic_raw/BALLISTIC_70              frame        (shape->[218,8])
# /ballistic_raw/BALLISTIC_700             frame        (shape->[192,8])
# /ballistic_raw/BALLISTIC_701             frame        (shape->[290,8])
# /ballistic_raw/BALLISTIC_702             frame        (shape->[257,8])
# /ballistic_raw/BALLISTIC_703             frame        (shape->[330,8])
# /ballistic_raw/BALLISTIC_704             frame        (shape->[190,8])
# ...
# /ballistic_raw/BALLISTIC_797             frame        (shape->[187,8])
# /ballistic_raw/BALLISTIC_798             frame        (shape->[190,8])
# /ballistic_raw/BALLISTIC_799             frame        (shape->[335,8])
# /ballistic_raw/BALLISTIC_8               frame        (shape->[236,8])
# /ballistic_raw/BALLISTIC_80              frame        (shape->[290,8])
# /ballistic_raw/BALLISTIC_800             frame        (shape->[201,8])
# /ballistic_raw/BALLISTIC_801             frame        (shape->[208,8])
# /ballistic_raw/BALLISTIC_802             frame        (shape->[197,8])
# /ballistic_raw/BALLISTIC_803             frame        (shape->[451,8])
# /ballistic_raw/BALLISTIC_804             frame        (shape->[180,8])
# /ballistic_raw/BALLISTIC_805             frame        (shape->[273,8])
# /ballistic_raw/BALLISTIC_806             frame        (shape->[285,8])
# /ballistic_raw/BALLISTIC_807             frame        (shape->[321,8])
# /ballistic_raw/BALLISTIC_808             frame        (shape->[274,8])
# /ballistic_raw/BALLISTIC_809             frame        (shape->[171,8])
# /ballistic_raw/BALLISTIC_81              frame        (shape->[194,8])
# /ballistic_raw/BALLISTIC_810             frame        (shape->[338,8])
# /ballistic_raw/BALLISTIC_811             frame        (shape->[252,8])
# /ballistic_raw/BALLISTIC_812             frame        (shape->[222,8])
# /ballistic_raw/BALLISTIC_813             frame        (shape->[231,8])
# /ballistic_raw/BALLISTIC_814             frame        (shape->[263,8])
# /ballistic_raw/BALLISTIC_815             frame        (shape->[246,8])
# /ballistic_raw/BALLISTIC_816             frame        (shape->[395,8])
# /ballistic_raw/BALLISTIC_817             frame        (shape->[359,8])
# /ballistic_raw/BALLISTIC_818             frame        (shape->[201,8])
# /ballistic_raw/BALLISTIC_819             frame        (shape->[233,8])
# /ballistic_raw/BALLISTIC_82              frame        (shape->[365,8])
# /ballistic_raw/BALLISTIC_820             frame        (shape->[194,8])
# /ballistic_raw/BALLISTIC_821             frame        (shape->[214,8])
# /ballistic_raw/BALLISTIC_822             frame        (shape->[318,8])
# /ballistic_raw/BALLISTIC_823             frame        (shape->[278,8])
# /ballistic_raw/BALLISTIC_824             frame        (shape->[224,8])
# /ballistic_raw/BALLISTIC_825             frame        (shape->[227,8])
# /ballistic_raw/BALLISTIC_826             frame        (shape->[191,8])
# /ballistic_raw/BALLISTIC_827             frame        (shape->[200,8])
# /ballistic_raw/BALLISTIC_828             frame        (shape->[405,8])
# /ballistic_raw/BALLISTIC_829             frame        (shape->[280,8])
# /ballistic_raw/BALLISTIC_83              frame        (shape->[370,8])
# /ballistic_raw/BALLISTIC_830             frame        (shape->[170,8])
# /ballistic_raw/BALLISTIC_831             frame        (shape->[272,8])
# /ballistic_raw/BALLISTIC_832             frame        (shape->[240,8])
# /ballistic_raw/BALLISTIC_833             frame        (shape->[419,8])
# /ballistic_raw/BALLISTIC_834             frame        (shape->[194,8])
# /ballistic_raw/BALLISTIC_835             frame        (shape->[266,8])
# /ballistic_raw/BALLISTIC_836             frame        (shape->[274,8])
# /ballistic_raw/BALLISTIC_837             frame        (shape->[374,8])
# /ballistic_raw/BALLISTIC_838             frame        (shape->[328,8])
# /ballistic_raw/BALLISTIC_839             frame        (shape->[217,8])
# /ballistic_raw/BALLISTIC_84              frame        (shape->[185,8])
# /ballistic_raw/BALLISTIC_840             frame        (shape->[397,8])
# /ballistic_raw/BALLISTIC_841             frame        (shape->[357,8])
# /ballistic_raw/BALLISTIC_842             frame        (shape->[199,8])
# /ballistic_raw/BALLISTIC_843             frame        (shape->[193,8])
# /ballistic_raw/BALLISTIC_844             frame        (shape->[355,8])
# /ballistic_raw/BALLISTIC_845             frame        (shape->[220,8])
# /ballistic_raw/BALLISTIC_846             frame        (shape->[225,8])
# /ballistic_raw/BALLISTIC_847             frame        (shape->[188,8])
# /ballistic_raw/BALLISTIC_848             frame        (shape->[248,8])
# /ballistic_raw/BALLISTIC_849             frame        (shape->[249,8])
# /ballistic_raw/BALLISTIC_85              frame        (shape->[213,8])
# /ballistic_raw/BALLISTIC_850             frame        (shape->[307,8])
# /ballistic_raw/BALLISTIC_851             frame        (shape->[289,8])
# /ballistic_raw/BALLISTIC_852             frame        (shape->[194,8])
# /ballistic_raw/BALLISTIC_853             frame        (shape->[177,8])
# /ballistic_raw/BALLISTIC_854             frame        (shape->[175,8])
# /ballistic_raw/BALLISTIC_855             frame        (shape->[373,8])
# /ballistic_raw/BALLISTIC_856             frame        (shape->[359,8])
# /ballistic_raw/BALLISTIC_857             frame        (shape->[245,8])
# /ballistic_raw/BALLISTIC_858             frame        (shape->[194,8])
# /ballistic_raw/BALLISTIC_859             frame        (shape->[185,8])
# /ballistic_raw/BALLISTIC_86              frame        (shape->[209,8])
# /ballistic_raw/BALLISTIC_860             frame        (shape->[305,8])
# /ballistic_raw/BALLISTIC_861             frame        (shape->[188,8])
# /ballistic_raw/BALLISTIC_862             frame        (shape->[412,8])
# /ballistic_raw/BALLISTIC_863             frame        (shape->[240,8])
# /ballistic_raw/BALLISTIC_864             frame        (shape->[213,8])
# /ballistic_raw/BALLISTIC_865             frame        (shape->[217,8])
# /ballistic_raw/BALLISTIC_866             frame        (shape->[351,8])
# /ballistic_raw/BALLISTIC_867             frame        (shape->[179,8])
# /ballistic_raw/BALLISTIC_868             frame        (shape->[382,8])
# /ballistic_raw/BALLISTIC_869             frame        (shape->[278,8])
# /ballistic_raw/BALLISTIC_87              frame        (shape->[299,8])
# /ballistic_raw/BALLISTIC_870             frame        (shape->[272,8])
# /ballistic_raw/BALLISTIC_871             frame        (shape->[273,8])
# /ballistic_raw/BALLISTIC_872             frame        (shape->[217,8])
# /ballistic_raw/BALLISTIC_873             frame        (shape->[208,8])
# /ballistic_raw/BALLISTIC_874             frame        (shape->[225,8])
# /ballistic_raw/BALLISTIC_875             frame        (shape->[211,8])
# /ballistic_raw/BALLISTIC_876             frame        (shape->[175,8])
# /ballistic_raw/BALLISTIC_877             frame        (shape->[191,8])
# /ballistic_raw/BALLISTIC_878             frame        (shape->[246,8])
# /ballistic_raw/BALLISTIC_879             frame        (shape->[193,8])
# /ballistic_raw/BALLISTIC_88              frame        (shape->[258,8])
# /ballistic_raw/BALLISTIC_880             frame        (shape->[233,8])
# /ballistic_raw/BALLISTIC_881             frame        (shape->[296,8])
# /ballistic_raw/BALLISTIC_882             frame        (shape->[178,8])
# /ballistic_raw/BALLISTIC_883             frame        (shape->[285,8])
# /ballistic_raw/BALLISTIC_884             frame        (shape->[375,8])
# /ballistic_raw/BALLISTIC_885             frame        (shape->[197,8])
# /ballistic_raw/BALLISTIC_886             frame        (shape->[291,8])
# /ballistic_raw/BALLISTIC_887             frame        (shape->[183,8])
# /ballistic_raw/BALLISTIC_888             frame        (shape->[214,8])
# /ballistic_raw/BALLISTIC_889             frame        (shape->[181,8])
# /ballistic_raw/BALLISTIC_89              frame        (shape->[245,8])
# /ballistic_raw/BALLISTIC_890             frame        (shape->[402,8])
# /ballistic_raw/BALLISTIC_891             frame        (shape->[190,8])
# /ballistic_raw/BALLISTIC_892             frame        (shape->[186,8])
# /ballistic_raw/BALLISTIC_893             frame        (shape->[339,8])
# /ballistic_raw/BALLISTIC_894             frame        (shape->[270,8])
# /ballistic_raw/BALLISTIC_895             frame        (shape->[198,8])
# /ballistic_raw/BALLISTIC_896             frame        (shape->[214,8])
# /ballistic_raw/BALLISTIC_897             frame        (shape->[352,8])
# /ballistic_raw/BALLISTIC_898             frame        (shape->[237,8])
# /ballistic_raw/BALLISTIC_899             frame        (shape->[259,8])
# /ballistic_raw/BALLISTIC_9               frame        (shape->[202,8])
# /ballistic_raw/BALLISTIC_90              frame        (shape->[398,8])
# /ballistic_raw/BALLISTIC_900             frame        (shape->[179,8])
# /ballistic_raw/BALLISTIC_901             frame        (shape->[168,8])
# /ballistic_raw/BALLISTIC_902             frame        (shape->[391,8])
# /ballistic_raw/BALLISTIC_903             frame        (shape->[187,8])
# /ballistic_raw/BALLISTIC_904             frame        (shape->[242,8])
# /ballistic_raw/BALLISTIC_905             frame        (shape->[275,8])
# /ballistic_raw/BALLISTIC_906             frame        (shape->[259,8])
# /ballistic_raw/BALLISTIC_907             frame        (shape->[311,8])
# /ballistic_raw/BALLISTIC_908             frame        (shape->[241,8])
# /ballistic_raw/BALLISTIC_909             frame        (shape->[412,8])
# /ballistic_raw/BALLISTIC_91              frame        (shape->[268,8])
# /ballistic_raw/BALLISTIC_910             frame        (shape->[231,8])
# /ballistic_raw/BALLISTIC_911             frame        (shape->[250,8])
# /ballistic_raw/BALLISTIC_912             frame        (shape->[177,8])
# /ballistic_raw/BALLISTIC_913             frame        (shape->[325,8])
# /ballistic_raw/BALLISTIC_914             frame        (shape->[177,8])
# /ballistic_raw/BALLISTIC_915             frame        (shape->[185,8])
# /ballistic_raw/BALLISTIC_916             frame        (shape->[192,8])
# /ballistic_raw/BALLISTIC_917             frame        (shape->[401,8])
# /ballistic_raw/BALLISTIC_918             frame        (shape->[250,8])
# /ballistic_raw/BALLISTIC_919             frame        (shape->[364,8])
# /ballistic_raw/BALLISTIC_92              frame        (shape->[210,8])
# /ballistic_raw/BALLISTIC_920             frame        (shape->[223,8])
# /ballistic_raw/BALLISTIC_921             frame        (shape->[234,8])
# /ballistic_raw/BALLISTIC_922             frame        (shape->[226,8])
# /ballistic_raw/BALLISTIC_923             frame        (shape->[260,8])
# /ballistic_raw/BALLISTIC_924             frame        (shape->[172,8])
# /ballistic_raw/BALLISTIC_925             frame        (shape->[190,8])
# /ballistic_raw/BALLISTIC_926             frame        (shape->[182,8])
# /ballistic_raw/BALLISTIC_927             frame        (shape->[399,8])
# /ballistic_raw/BALLISTIC_928             frame        (shape->[236,8])
# /ballistic_raw/BALLISTIC_929             frame        (shape->[180,8])
# /ballistic_raw/BALLISTIC_93              frame        (shape->[251,8])
# /ballistic_raw/BALLISTIC_930             frame        (shape->[317,8])
# /ballistic_raw/BALLISTIC_931             frame        (shape->[196,8])
# /ballistic_raw/BALLISTIC_932             frame        (shape->[220,8])
# /ballistic_raw/BALLISTIC_933             frame        (shape->[252,8])
# /ballistic_raw/BALLISTIC_934             frame        (shape->[201,8])
# /ballistic_raw/BALLISTIC_935             frame        (shape->[240,8])
# /ballistic_raw/BALLISTIC_936             frame        (shape->[264,8])
# /ballistic_raw/BALLISTIC_937             frame        (shape->[287,8])
# /ballistic_raw/BALLISTIC_938             frame        (shape->[250,8])
# /ballistic_raw/BALLISTIC_939             frame        (shape->[358,8])
# /ballistic_raw/BALLISTIC_94              frame        (shape->[254,8])
# /ballistic_raw/BALLISTIC_940             frame        (shape->[218,8])
# /ballistic_raw/BALLISTIC_941             frame        (shape->[194,8])
# /ballistic_raw/BALLISTIC_942             frame        (shape->[252,8])
# /ballistic_raw/BALLISTIC_943             frame        (shape->[223,8])
# /ballistic_raw/BALLISTIC_944             frame        (shape->[219,8])
# /ballistic_raw/BALLISTIC_945             frame        (shape->[184,8])
# /ballistic_raw/BALLISTIC_946             frame        (shape->[208,8])
# /ballistic_raw/BALLISTIC_947             frame        (shape->[230,8])
# /ballistic_raw/BALLISTIC_948             frame        (shape->[199,8])
# /ballistic_raw/BALLISTIC_949             frame        (shape->[191,8])
# /ballistic_raw/BALLISTIC_95              frame        (shape->[281,8])
# /ballistic_raw/BALLISTIC_950             frame        (shape->[295,8])
# /ballistic_raw/BALLISTIC_951             frame        (shape->[240,8])
# /ballistic_raw/BALLISTIC_952             frame        (shape->[206,8])
# /ballistic_raw/BALLISTIC_953             frame        (shape->[190,8])
# /ballistic_raw/BALLISTIC_954             frame        (shape->[185,8])
# /ballistic_raw/BALLISTIC_955             frame        (shape->[435,8])
# /ballistic_raw/BALLISTIC_956             frame        (shape->[185,8])
# /ballistic_raw/BALLISTIC_957             frame        (shape->[378,8])
# /ballistic_raw/BALLISTIC_958             frame        (shape->[185,8])
# /ballistic_raw/BALLISTIC_959             frame        (shape->[185,8])
# /ballistic_raw/BALLISTIC_96              frame        (shape->[335,8])
# /ballistic_raw/BALLISTIC_960             frame        (shape->[329,8])
# /ballistic_raw/BALLISTIC_961             frame        (shape->[357,8])
# /ballistic_raw/BALLISTIC_962             frame        (shape->[365,8])
# /ballistic_raw/BALLISTIC_963             frame        (shape->[198,8])
# /ballistic_raw/BALLISTIC_964             frame        (shape->[320,8])
# /ballistic_raw/BALLISTIC_965             frame        (shape->[258,8])
# /ballistic_raw/BALLISTIC_966             frame        (shape->[237,8])
# /ballistic_raw/BALLISTIC_967             frame        (shape->[201,8])
# /ballistic_raw/BALLISTIC_968             frame        (shape->[169,8])
# /ballistic_raw/BALLISTIC_969             frame        (shape->[240,8])
# /ballistic_raw/BALLISTIC_97              frame        (shape->[332,8])
# /ballistic_raw/BALLISTIC_970             frame        (shape->[402,8])
# /ballistic_raw/BALLISTIC_971             frame        (shape->[204,8])
# /ballistic_raw/BALLISTIC_972             frame        (shape->[196,8])
# /ballistic_raw/BALLISTIC_973             frame        (shape->[218,8])
# /ballistic_raw/BALLISTIC_974             frame        (shape->[165,8])
# /ballistic_raw/BALLISTIC_975             frame        (shape->[282,8])
# /ballistic_raw/BALLISTIC_976             frame        (shape->[356,8])
# /ballistic_raw/BALLISTIC_977             frame        (shape->[267,8])
# /ballistic_raw/BALLISTIC_978             frame        (shape->[182,8])
# /ballistic_raw/BALLISTIC_979             frame        (shape->[253,8])
# /ballistic_raw/BALLISTIC_98              frame        (shape->[167,8])
# /ballistic_raw/BALLISTIC_980             frame        (shape->[237,8])
# /ballistic_raw/BALLISTIC_981             frame        (shape->[184,8])
# /ballistic_raw/BALLISTIC_982             frame        (shape->[218,8])
# /ballistic_raw/BALLISTIC_983             frame        (shape->[205,8])
# /ballistic_raw/BALLISTIC_984             frame        (shape->[187,8])
# /ballistic_raw/BALLISTIC_985             frame        (shape->[246,8])
# /ballistic_raw/BALLISTIC_986             frame        (shape->[292,8])
# /ballistic_raw/BALLISTIC_987             frame        (shape->[368,8])
# /ballistic_raw/BALLISTIC_988             frame        (shape->[176,8])
# /ballistic_raw/BALLISTIC_989             frame        (shape->[355,8])
# /ballistic_raw/BALLISTIC_99              frame        (shape->[200,8])
# /ballistic_raw/BALLISTIC_990             frame        (shape->[202,8])
# /ballistic_raw/BALLISTIC_991             frame        (shape->[255,8])
# /ballistic_raw/BALLISTIC_992             frame        (shape->[250,8])
# /ballistic_raw/BALLISTIC_993             frame        (shape->[203,8])
# /ballistic_raw/BALLISTIC_994             frame        (shape->[187,8])
# /ballistic_raw/BALLISTIC_995             frame        (shape->[207,8])
# /ballistic_raw/BALLISTIC_996             frame        (shape->[181,8])
# /ballistic_raw/BALLISTIC_997             frame        (shape->[197,8])
# /ballistic_raw/BALLISTIC_998             frame        (shape->[188,8])
# /ballistic_raw/BALLISTIC_999             frame        (shape->[195,8])

# %% [markdown]
# ## Splitting the data

# %%
def train_val_test_split(data, tts = (0.7, 0.1, 0.2), shuffle=False):
    '''Split data into train, validation and test sets according to `tts` tuple
    
    By default, tts = (train, val, test) = (0.7, 0.1, 0.2)
    '''
    assert sum(tts) == 1
    
    if shuffle:
        data = np.random.shuffle(data)
    
    h = len(data)
    train = data[:int(h * tts[0])]
    val = data[int(h * tts[0]) : int(h * np.round(tts[0] + tts[1], 4))]
    test = data[int(h * np.round(tts[0] + tts[1], 4)) : int(h * sum(tts))]

    return train, val, test

# %%
# Train-val-test split data
data_keys = sorted([key for key in dset.keys() if 'raw' in key])
# Test data       = 20% of total keys
# Validation data = 10% of total keys
# Train data      = 70% of total keys
train_keys, val_keys, test_keys = train_val_test_split(
    data_keys, (0.7, 0.1, 0.2), shuffle=False)

print(f'Train keys: {len(train_keys):>5} -> {len(train_keys)/len(data_keys) * 100}%')
print(f'Valid keys: {len(val_keys):>5} -> {len(val_keys)/len(data_keys) * 100}%')
print(f'Test keys:  {len(test_keys):>5} -> {len(test_keys)/len(data_keys) * 100}%')
# Out:
# Train keys:   700 -> 70.0%
# Valid keys:   100 -> 10.0%
# Test keys:    200 -> 20.0%

# %% [markdown]
# ## Invertible trajectory pre-processing transform

# %%
class RelativeTrajectory():
    def __init__(self, df, diff=False, ref_point=20):

        self.diff = diff
        self.ref_point = ref_point
        
        data = np.array(df.drop('t', 1))
        
        # Remember first state
        self.start_state = data[0].copy()
        
        # Make changes relative to the start state
        data -= self.start_state
        
        # Rotate coordinate system around Z axis, 
        # so X` axis will pass through the 20'th point
        # and Y` axis will represent deviation

        ## Calculate angle of rotation: arctan(y_r / x_r), where r is ref_point
        assert data.shape[0] >= ref_point
        self.theta = np.arctan(data[ref_point][1] / data[ref_point][0])

        ## Rotation matrix for XY plane around Z axis
        ## Perform rotation for coordinates
        data[:, :3] = self.rotate_Z(data[:, :3], self.theta)

        ## Perform rotation for velocities
        data[:, 3:6] = self.rotate_Z(data[:, 3:6], self.theta)

        # Scale data to kilometers
        data /= 1000

        self.first_diff_elem = None
        if diff:
            self.first_diff_elem = data[0].copy()
            data = np.diff(data, axis=0)    
        
        self.data = data
        
    def restore(self, columns, ts=1, config=None):
        
        assert ts > 0
        
        if config:
            self.set_info(config)
        
        # Restore diff data
        if self.diff:
            data = np.r_[np.expand_dims(self.first_diff_elem, 0), np.cumsum(self.data, axis=0)]
        else:         
            data = self.data.copy()
        
        # Scale data from km back to meters
        data *= 1000
        
        ## Rotation matrix for XY plane around Z axis
        ## Perform rotation for coordinates
        data[:, 0:3] = self.rotate_Z(data[:, 0:3], -self.theta)

        ## Perform rotation for velocities
        data[:, 3:6] = self.rotate_Z(data[:, 3:6], -self.theta)
        
        # Make changes absolute
        data += self.start_state

        # Restore Pandas.DataFrame format
        t = np.arange(0, data.shape[0], ts)
        data = np.c_[data, t] 
        data = pd.DataFrame(data, columns=columns)
        
        return data
        
    @staticmethod
    def rotate_Z(data, theta):
        """Rotate data around the Z axis using matrix R"""
        
        R = np.array([
            [np.cos(theta), -np.sin(theta), 0],
            [np.sin(theta),  np.cos(theta), 0],
            [            0,              0, 1]
        ])
        return data @ R.T
    
    def info(self):
        return {
            'ref_point' : self.ref_point,
            'diff' : self.diff,
            'start_state' : self.start_state,
            'first_diff_elem' : self.first_diff_elem,
            'theta' : self.theta
        }
    
    def set_info(self, config):
        self.ref_point = config['ref_point']
        self.diff = config['diff']
        self.start_point = config['start_point']
        self.first_diff_elem = config['first_diff_elem']
        self.theta = config['theta']

# %% [markdown]
# ## Standardizing data

# %%
from sklearn.preprocessing import StandardScaler

# Calculate mean and variance over all training set 
print('Calculating mean and variance over all training data...')
scaler = StandardScaler()
means = []
for train_key in tqdm(train_keys):
    traj = RelativeTrajectory(dset[train_key])
    means.append(traj.data.mean(axis=0))

scaler.fit(np.array(means))
# Out:
# Calculating mean and variance over all training data...
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-ce4fa33579e2> in <module>
#       5 scaler = StandardScaler()
#       6 means = []
# ----> 7 for train_key in tqdm(train_keys):
#       8     traj = RelativeTrajectory(dset[train_key])
#       9     means.append(traj.data.mean(axis=0))
#
# NameError: name 'tqdm' is not defined

# %% [markdown]
# ## Recurrent block

# %%
# Our recurrent block
class ModuleRNN(nn.Module):
    """
    Implement the scheme above as torch module
    torch style
    
    """
    def __init__(self, vect_dim=3, rnn_num_units=64):
        super(self.__class__,self).__init__()
        self.num_units = rnn_num_units
        
#         our linear layer
        self.rnn_update = nn.Linear(vect_dim + rnn_num_units, rnn_num_units)
        self.rnn_to_logits = nn.Linear(rnn_num_units, vect_dim)
        
    def forward(self, x, h_prev):
        """
        This method computes h_next(x, h_prev) and log P(x_next | h_next)
        We'll call it repeatedly to produce the whole sequence.
        
        :param x: batch of character ids, containing vector of int64
        :param h_prev: previous rnn hidden states, containing matrix [batch, rnn_num_units] of float32
        """
        
        x_and_h = torch.cat([x, h_prev], dim=-1) # [x, h_prev]
        h_next = self.rnn_update(x_and_h)
        
        h_next = torch.tanh(h_next) # activation function
        
        assert h_next.size() == h_prev.size()
        
        #compute logits for next character probs
        logits = self.rnn_to_logits(h_next) 
        
        return h_next, logits
    
    def initial_state(self, batch_size):
        """ return rnn state before it processes first input (aka h0) """
        return torch.zeros(batch_size, self.num_units, requires_grad=True)

# %% [markdown]
# ## RNN Loop

# %%
def rnn_loop(trajectories_rnn, batch_ix):
    """
    Computes log P(next_character) for all time-steps in names_ix
    :param names_ix: an int32 matrix of shape [batch, time], output of to_matrix(names)
    """
    batch_size, max_length = batch_ix.size()
    hid_state = trajectories_rnn.initial_state(batch_size)
    logprobs = []

    for x_t in batch_ix.transpose(0,1):
        hid_state, logits = trajectories_rnn(x_t, hid_state)  # <-- here we call your one-step code
        logprobs.append(logits)
        
    return torch.stack(logprobs, dim=1)

# %%
from IPython.display import clear_output
from random import sample

# %%
trajectories_rnn = ModuleRNN()
criterion = nn.MSELoss() # nn.CrossEntropyLoss()
opt = torch.optim.Adam(trajectories_rnn.parameters())
history = []

# %% [markdown]
# ## The training loop

# %%
MAX_LENGTH = 3 #vect_dim


for i in range(1000):
    opt.zero_grad()
    
    batch_ix = to_matrix(sample(names, 32), max_len=MAX_LENGTH)
    batch_ix = torch.tensor(batch_ix, dtype=torch.int64)
    
    logp_seq = rnn_loop(char_rnn, batch_ix)
    
    # compute loss
    predictions_logp = logp_seq[:, :-1] # YOUR CODE HERE
    actual_next_tokens = batch_ix[:, 1:] # YOUR CODE HERE
    
#     print(predictions_logp.shape, actual_next_tokens.shape)
    loss = criterion(
        predictions_logp.contiguous().view(-1, num_tokens),
        actual_next_tokens.contiguous().view(-1)
    ) 
    # YOUR CODE HERE
    
    # train with backprop
    loss.backward()
    opt.step()
    
    # YOUR CODE HERE
    
    history.append(loss.data.numpy())
    if (i+1)%100==0:
        clear_output(True)
        plt.plot(history,label='loss')
        plt.legend()
        plt.show()

assert np.mean(history[:10]) > np.mean(history[-10:]), "RNN didn't converge."
